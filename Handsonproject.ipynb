# %% [markdown]
# # **Liabraries Importing**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.api as sm

# %% [markdown]
# # **Dataset Retrieving**

# %%
df = pd.read_excel("/content/Sales_Data.xlsx")

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.head()
# Out:
#         Date       Country    City     Product  Year Quarter      Month  \
# 0 2018-11-24         Syria    Hama      Laptop  2018      Q4 2018-11-24
# 1 2019-05-10  Saudi Arabia    Abha      Laptop  2019      Q2 2019-05-10
# 2 2020-09-30         Syria    Hama     Printer  2020      Q3 2020-09-30
# 3 2019-05-27     Palestine  Nablus  Cell Phone  2019      Q2 2019-05-27
# 4 2017-07-08  Saudi Arabia  Jeddah  Cell Phone  2017      Q3 2017-07-08
#
#   Transaction ID  Gender  Units Sold  Unit Cost  Unit Selling Price  \
# 0      ID - 4237    Male          50       5761                9567
# 1      ID - 4351    Male          24       2708                4260
# 2      ID - 4465  Female          46       7014               10795
# 3      ID - 4579  Female          49       8475               12500
# 4      ID - 4693  Female          77       4644                8561
#
#    Total Cost  Tota Sales  Total Profit Unnamed: 15
# 0      288050      478350        190300         NaN
# 1       64992      102240         37248         NaN
# 2      322644      496570        173926         NaN
# 3      415275      612500        197225         NaN
# 4      357588      659197        301609         NaN

# %%
df["Country"].value_counts()
# Out:
# Country
# Syria           1461
# Saudi Arabia    1461
# Palestine       1461
# Egypt           1461
# Name: count, dtype: int64
